# %%
o = pd.read_csv("ODI data.csv")
o.drop(columns=["Unnamed: 0", "Unnamed: 13"], inplace=True)
o.head(1)
# Out:
#                  Player       Span  Mat Inns  NO   Runs    HS    Ave     BF  \
# 0  SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*  44.83  21367
#
#       SR 100  50   0
# 0  86.23  49  96  20

# %%
o["end date"]= o["Span"].str.split("-").str.get(1).astype(int)
o
# Out:
#                            Player       Span  Mat Inns  NO   Runs    HS  \
# 0            SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*
# 1     KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234   169
# 2            RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704   164
# 3         ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430   189
# 4      DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650   144
# ...                           ...        ...  ...  ...  ..    ...   ...
# 2495              ZS Ansari (ENG)  2015-2015    1    -   -      -     -
# 2496         Ariful Haque (BDESH)  2018-2018    1    -   -      -     -
# 2497           Ashfaq Ahmed (PAK)  1994-1994    3    -   -      -     -
# 2498               MD Bailey (NZ)  1998-1998    1    -   -      -     -
# 2499               GR Beard (AUS)  1981-1981    2    -   -      -     -
#
#         Ave     BF     SR 100  50   0 initials      surname        country  \
# ...

# %%
o["start date"] = o["start date"].astype(int)

# %%
o.columns   = o.columns.str.lower()
o.head(1)
# Out:
#                  player       span  mat inns  no   runs    hs    ave     bf  \
# 0  SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*  44.83  21367
#
#       sr 100  50   0 initials    surname  country  start date  end date
# 0  86.23  49  96  20       SR  Tendulkar  (INDIA)        1989      2012

# %%
o["ave"] = o["ave"].str.replace("-", "0" ).astype(float)

# %%
o.sort_values(["ave"], ascending=False, inplace=True)

# %%
cred = o["mat"]>10
rec = o["end date"] == 2019
eng = o["country"] == "(ENG)"
ind = o["country"] == "(INDIA)"
aus = o["country"] == "(AUS)"
pak = o["country"] == "(PAK)"



o[cred & rec & pak ].head(40)
# Out:
#                      player       span  mat inns  no  runs    hs    ave    bf  \
# 139        Babar Azam (PAK)  2015-2019   74   72  10  3359  125*  54.17  3857
# 233      Fakhar Zaman (PAK)  2017-2019   46   46   4  1958  210*  46.61  2056
# 274      Haris Sohail (PAK)  2013-2019   41   40   5  1614   130  46.11  1895
# 406        Imad Wasim (PAK)  2015-2019   53   39  16   952   63*  41.39   868
# 34       Shoaib Malik (PAK)  1999-2019  287  258  40  7534   143  34.55  9199
# 145        Umar Akmal (PAK)  2009-2019  121  110  17  3194  102*  34.34  3712
# 203    Sarfaraz Ahmed (PAK)  2007-2019  116   90  22  2302   105  33.85  2622
# 493   Mohammad Rizwan (PAK)  2015-2019   32   28   7   705   115  33.57   787
# 49    Mohammad Hafeez (PAK)  2003-2019  218  216  15  6614  140*  32.90  8633
# 716          Asif Ali (PAK)  2018-2019   18   14   1   361    52  27.76   280
# 739       Shadab Khan (PAK)  2017-2019   43   22   9   337    54  25.92   491
# ...

# %%
o = pd.read_csv("ODI data.csv")
o.drop(columns=["Unnamed: 0", "Unnamed: 13"], inplace=True)
o.head(1)
# Out:
#                  Player       Span  Mat Inns  NO   Runs    HS    Ave     BF  \
# 0  SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*  44.83  21367
#
#       SR 100  50   0
# 0  86.23  49  96  20

# %%
o["end date"]= o["Span"].str.split("-").str.get(1).astype(int)
o
# Out:
#                            Player       Span  Mat Inns  NO   Runs    HS  \
# 0            SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*
# 1     KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234   169
# 2            RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704   164
# 3         ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430   189
# 4      DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650   144
# ...                           ...        ...  ...  ...  ..    ...   ...
# 2495              ZS Ansari (ENG)  2015-2015    1    -   -      -     -
# 2496         Ariful Haque (BDESH)  2018-2018    1    -   -      -     -
# 2497           Ashfaq Ahmed (PAK)  1994-1994    3    -   -      -     -
# 2498               MD Bailey (NZ)  1998-1998    1    -   -      -     -
# 2499               GR Beard (AUS)  1981-1981    2    -   -      -     -
#
#         Ave     BF     SR 100  50   0 initials      surname        country  \
# ...

# %%
o["start date"] = o["start date"].astype(int)

# %%
o.columns   = o.columns.str.lower()
o.head(1)
# Out:
#                  player       span  mat inns  no   runs    hs    ave     bf  \
# 0  SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*  44.83  21367
#
#       sr 100  50   0 initials    surname  country  start date  end date
# 0  86.23  49  96  20       SR  Tendulkar  (INDIA)        1989      2012

# %%
o["ave"] = o["ave"].str.replace("-", "0" ).astype(float)

# %%
o.sort_values(["ave"], ascending=False, inplace=True)

# %%
cred = o["mat"]>10
rec = o["end date"] == 2019
eng = o["country"] == "(ENG)"
ind = o["country"] == "(INDIA)"
aus = o["country"] == "(AUS)"
pak = o["country"] == "(PAK)"



o[cred & rec & pak ].head(40)
# Out:
#                      player       span  mat inns  no  runs    hs    ave    bf  \
# 139        Babar Azam (PAK)  2015-2019   74   72  10  3359  125*  54.17  3857
# 233      Fakhar Zaman (PAK)  2017-2019   46   46   4  1958  210*  46.61  2056
# 274      Haris Sohail (PAK)  2013-2019   41   40   5  1614   130  46.11  1895
# 406        Imad Wasim (PAK)  2015-2019   53   39  16   952   63*  41.39   868
# 34       Shoaib Malik (PAK)  1999-2019  287  258  40  7534   143  34.55  9199
# 145        Umar Akmal (PAK)  2009-2019  121  110  17  3194  102*  34.34  3712
# 203    Sarfaraz Ahmed (PAK)  2007-2019  116   90  22  2302   105  33.85  2622
# 493   Mohammad Rizwan (PAK)  2015-2019   32   28   7   705   115  33.57   787
# 49    Mohammad Hafeez (PAK)  2003-2019  218  216  15  6614  140*  32.90  8633
# 716          Asif Ali (PAK)  2018-2019   18   14   1   361    52  27.76   280
# 739       Shadab Khan (PAK)  2017-2019   43   22   9   337    54  25.92   491
# ...

# %%
o
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 o
#
# NameError: name 'o' is not defined
